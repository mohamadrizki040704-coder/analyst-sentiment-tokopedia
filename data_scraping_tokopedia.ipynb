# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import time

PACKAGE_NAME = 'com.tokopedia.tkpd'
BAHASA ='id'
NEGARA ='id'
TARGET_ULASAN = 15000

df.to_csv('ulasan_tokopedia.csv', index=False)
print (f"scraping siap : {TARGET_ULASAN}")
# Out:
# scraping siap : 15000
